# %%
import json
import pandas as pd 
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
import numpy as np

# %%
df = pd.read_csv('imdb_top_1000.csv', index_col='Series_Title')
df = df.dropna(subset=['Gross'])
df['Gross'] = df['Gross'].apply(lambda x: int(x.replace(",", "")))
df['Released_Year'] = pd.to_numeric(df['Released_Year'], errors='coerce')
df
# Out:
#                                                                 Poster_Link  \
# Series_Title
# The Shawshank Redemption  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# The Godfather             https://m.media-amazon.com/images/M/MV5BM2MyNj...
# The Dark Knight           https://m.media-amazon.com/images/M/MV5BMTMxNT...
# The Godfather: Part II    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 12 Angry Men              https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ...                                                                     ...
# Giù la testa              https://m.media-amazon.com/images/M/MV5BYjRmY2...
# Kelly's Heroes            https://m.media-amazon.com/images/M/MV5BMzAyND...
# The Jungle Book           https://m.media-amazon.com/images/M/MV5BMjAwMT...
# A Hard Day's Night        https://m.media-amazon.com/images/M/MV5BZjQyMG...
# From Here to Eternity     https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
# ...

# %%
#print(X_test.dtypes)
X=df[['Released_Year','IMDB_Rating','No_of_Votes']]
y=df['Gross']

# %%
X_train,X_test,y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
for depth in range(1, 11):
    clf = DecisionTreeClassifier(max_depth=depth)
    clf.fit(X_train, y_train)  
    test_pred = clf.predict(X_test)  
   
    test_correct = test_pred == y_test.values  
    test_accuracy = np.mean(test_correct)  

    print(f'max_depth={depth} | Test_Accuracy: {test_accuracy:.2f}')
# Out:
# max_depth=1 | Test_Accuracy: 0.00
# max_depth=2 | Test_Accuracy: 0.00
# max_depth=3 | Test_Accuracy: 0.00
# max_depth=4 | Test_Accuracy: 0.00
# max_depth=5 | Test_Accuracy: 0.00
# max_depth=6 | Test_Accuracy: 0.00
# max_depth=7 | Test_Accuracy: 0.00
# max_depth=8 | Test_Accuracy: 0.00
# max_depth=9 | Test_Accuracy: 0.00
# max_depth=10 | Test_Accuracy: 0.00

# %%
for depth in range(1, 11):
    clf = DecisionTreeClassifier(max_depth=depth)
    clf.fit(X_train, y_train)  
    train_pred = clf.predict(X_train)  
   
    train_correct = train_pred == y_train.values  
    train_accuracy = np.mean(train_correct)  

    print(f'max_depth={depth} | Train_Accuracy: {train_accuracy:.2f}')
# Out:
# max_depth=1 | Train_Accuracy: 0.01
# max_depth=2 | Train_Accuracy: 0.02
# max_depth=3 | Train_Accuracy: 0.02
# max_depth=4 | Train_Accuracy: 0.03
# max_depth=5 | Train_Accuracy: 0.05
# max_depth=6 | Train_Accuracy: 0.06
# max_depth=7 | Train_Accuracy: 0.08
# max_depth=8 | Train_Accuracy: 0.11
# max_depth=9 | Train_Accuracy: 0.13
# max_depth=10 | Train_Accuracy: 0.14

# %%
test_pred = clf.predict(X_test)
results = X_test.copy()
results['Actual'] = y_test
results['Predicted'] = test_pred
wrong_preds = results[results['Actual'] != results['Predicted']]
for idx, row in wrong_preds.head(5).iterrows():
    print(f"\n {idx}")
    for col in X_test.columns:
        print(f"  {col}: {row[col]}")
    print(f"\n  Actual: {row['Actual']}")
    print(f"  Predicted: {row['Predicted']}")
# Out:
#  Under sandet
#   Released_Year: 2015.0
#   IMDB_Rating: 7.8
#   No_of_Votes: 35539.0
#
#   Actual: 435266.0
#   Predicted: 1305.0
#
#  Dogville
#   Released_Year: 2003.0
#   IMDB_Rating: 8.0
#   No_of_Votes: 137963.0
#
#   Actual: 1530386.0
#   Predicted: 1305.0
#
#  All That Jazz
#   Released_Year: 1979.0
#   IMDB_Rating: 7.9
#   No_of_Votes: 28223.0
#
#   Actual: 37823676.0
#   Predicted: 1305.0
#
#  Ferris Bueller's Day Off
#   Released_Year: 1986.0
#   IMDB_Rating: 7.8
#   No_of_Votes: 321382.0
#
#   Actual: 70136369.0
#   Predicted: 1305.0
#
#  A Clockwork Orange
#   Released_Year: 1971.0
#   IMDB_Rating: 8.3
#   No_of_Votes: 757904.0
#
#   Actual: 6207725.0
#   Predicted: 56954992.0
