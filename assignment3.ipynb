# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('imdb_top_1000.csv', index_col='Series_Title')
df = df.dropna(subset=['Gross'])
df['Gross'] = df['Gross'].apply(lambda x: int(x.replace(",", "")))

# %%
df
# Out:
#                                                                 Poster_Link  \
# Series_Title
# The Shawshank Redemption  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# The Godfather             https://m.media-amazon.com/images/M/MV5BM2MyNj...
# The Dark Knight           https://m.media-amazon.com/images/M/MV5BMTMxNT...
# The Godfather: Part II    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 12 Angry Men              https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ...                                                                     ...
# Giù la testa              https://m.media-amazon.com/images/M/MV5BYjRmY2...
# Kelly's Heroes            https://m.media-amazon.com/images/M/MV5BMzAyND...
# The Jungle Book           https://m.media-amazon.com/images/M/MV5BMjAwMT...
# A Hard Day's Night        https://m.media-amazon.com/images/M/MV5BZjQyMG...
# From Here to Eternity     https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
# ...

# %%
from scipy.sparse import lil_matrix
import scipy.spatial.distance
import matplotlib.pyplot as plt

# %%
#gross income distances
target_movie_title = 'The Dark Knight'
target_movie_gross = df.loc[target_movie_title, 'Gross']


column_values = df['Gross'].values.reshape(-1, 1)
target_value_reshaped = np.array(target_movie_gross).reshape(1, -1)

distances = cdist(column_values, target_value_reshaped, metric='euclidean').flatten()
query_distances = list(zip(df.index,distances))
for movie_title, distances in sorted(query_distances, key=lambda x: x[1])[:10]:
    print(f"Movie: {movie_title}, Euclidean Distance: {distances}")
# Out:
# Movie: The Dark Knight, Euclidean Distance: 0.0
# Movie: Rogue One, Euclidean Distance: 2681120.0
# Movie: Incredibles 2, Euclidean Distance: 73723300.0
# Movie: The Dark Knight Rises, Euclidean Distance: 86719345.0
# Movie: The Avengers, Euclidean Distance: 88421103.0
# Movie: E.T. the Extra-Terrestrial, Euclidean Distance: 99747890.0
# Movie: Toy Story 4, Euclidean Distance: 100820436.0
# Movie: The Lion King, Euclidean Distance: 112074667.0
# Movie: Toy Story 3, Euclidean Distance: 119853564.0
# Movie: Titanic, Euclidean Distance: 124466935.0

# %%
#number of votes on imdb
target_movie_title = 'The Dark Knight'
target_movie_votes = df.loc[target_movie_title, 'No_of_Votes']


column_values = df['No_of_Votes'].values.reshape(-1, 1)
target_value_reshaped = np.array(target_movie_votes).reshape(1, -1)

distances = cdist(column_values, target_value_reshaped, metric='euclidean').flatten()
query_distances = list(zip(df.index,distances))
for movie_title, distances in sorted(query_distances, key=lambda x: x[1])[:10]:
   print(f"Movie: {movie_title}, Euclidean Distance: {distances}")
# Out:
# Movie: The Dark Knight, Euclidean Distance: 0.0
# Movie: The Shawshank Redemption, Euclidean Distance: 39878.0
# Movie: Inception, Euclidean Distance: 236190.0
# Movie: Fight Club, Euclidean Distance: 448492.0
# Movie: Pulp Fiction, Euclidean Distance: 477044.0
# Movie: Forrest Gump, Euclidean Distance: 494011.0
# Movie: The Matrix, Euclidean Distance: 626806.0
# Movie: The Lord of the Rings: The Fellowship of the Ring, Euclidean Distance: 641751.0
# Movie: The Lord of the Rings: The Return of the King, Euclidean Distance: 660474.0
# Movie: The Godfather, Euclidean Distance: 682865.0

# %%
#imdb rating
target_movie_title = 'The Dark Knight'
target_movie_rating = df.loc[target_movie_title, 'IMDB_Rating']


column_values = df['IMDB_Rating'].values.reshape(-1, 1)
target_value_reshaped = np.array(target_movie_rating).reshape(1, -1)

distances = cdist(column_values, target_value_reshaped, metric='euclidean').flatten()
query_distances = list(zip(df.index,distances))
for movie_title, distances in sorted(query_distances, key=lambda x: x[1])[:10]:
   print(f"Movie: {movie_title}, Euclidean Distance: {distances}")
# Out:
# Movie: The Dark Knight, Euclidean Distance: 0.0
# Movie: The Godfather: Part II, Euclidean Distance: 0.0
# Movie: 12 Angry Men, Euclidean Distance: 0.0
# Movie: The Lord of the Rings: The Return of the King, Euclidean Distance: 0.09999999999999964
# Movie: Pulp Fiction, Euclidean Distance: 0.09999999999999964
# Movie: Schindler's List, Euclidean Distance: 0.09999999999999964
# Movie: The Godfather, Euclidean Distance: 0.1999999999999993
# Movie: Inception, Euclidean Distance: 0.1999999999999993
# Movie: Fight Club, Euclidean Distance: 0.1999999999999993
# Movie: The Lord of the Rings: The Fellowship of the Ring, Euclidean Distance: 0.1999999999999993
